# %%
1 == 1 or 2 != 2
# Out:
# True

# %%
1 == 1 and 2 != 2
# Out:
# False

# %%
not (1 > 1)
# Out:
# True

# %%
2.0 == 2
# Out:
# True

# %%
'2' == 2
# Out:
# False

# %%
2 < 3 > 10
# Out:
# False

# %%
2 > True
# Out:
# True

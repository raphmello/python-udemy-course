# %%
def test():
    print("test")
test()
# Out:
# test

# %%
def say_hello(name='Default'):
    print(f"Hello, {name}")

# %%
say_hello("Raphael")
# Out:
# Hello, Raphael

# %%
say_hello()
# Out:
# Hello, Default

# %%
def create_tuple():
    return "Hello", "World"

create_tuple()
# Out:
# ('Hello', 'World')

# %%
name, surname = create_tuple()
print(name, surname)
# Out:
# Hello World

# %%
def my_func(*args):
    return sum(args)

# %%
my_func(1,2,3,4,5)
# Out:
# 15

# %%
def my_func(**kwargs):
    if 'fruit' in kwargs:
        print(kwargs['fruit'])
    else:
        print('no fruit')

my_func(fruit='apple')
# Out:
# apple

# %%
my_func()
# Out:
# no fruit

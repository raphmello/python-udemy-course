# %%
# %%writefile myfile.txt
# Hello this is a text file
# second line
# third line
# Out:
# Overwriting myfile.txt

# %%
my_file = open('myfile.txt')

# %%
pwd
# Out:
# 'C:\\workspace\\python-udemy-course\\section-03-data-structures'

# %%
my_file.read()
# Out:
# 'Hello this is a text file\nsecond line\nthird line\n'

# %%
my_file.read()
# Out:
# ''

# %%
my_file.seek(0)
# Out:
# 0

# %%
print(my_file.readlines())
# Out:
# ['Hello this is a text file\n', 'second line\n', 'third line\n']

# %%
my_file.close()

# %%
with open('myfile.txt') as my_new_file:
    print(my_new_file.read())
# Out:
# Hello this is a text file
# second line
# third line

# %%
with open('myfile2.txt',mode='w') as my_new_file:
    my_new_file.write("Hello this is a text file")

# %%
with open('myfile2.txt',mode='r') as my_new_file:
    print(my_new_file.read())
# Out:
# Hello this is a text file

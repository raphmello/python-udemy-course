# %%
my_list = [1,2,3]

# %%
my_list.append(4)
my_list
# Out:
# [1, 2, 3, 4]

# %%
my_list = ['String', 100, 23.2]
my_list
# Out:
# ['String', 100, 23.2]

# %%
len(my_list)
# Out:
# 3

# %%
my_list[1:]
# Out:
# [100, 23.2]

# %%
my_list[-1]
# Out:
# 23.2

# %%
another_list = [1,2,3]
new_list = my_list + another_list
new_list
# Out:
# ['String', 100, 23.2, 1, 2, 3]

# %%
new_list.pop()
new_list
# Out:
# ['String', 100, 23.2, 1, 2]

# %%
new_list.pop(1)
new_list
# Out:
# ['String', 23.2, 1, 2]

# %%
nums_list = [10,20,5,2,100,28,50]
nums_list.sort()
nums_list
# Out:
# [2, 5, 10, 20, 28, 50, 100]

# %%
nums_list.reverse()
nums_list
# Out:
# [100, 50, 28, 20, 10, 5, 2]

# %% [markdown]
# Dictionaries

# %%
my_dict = {
    'key1': 'value1',
    'key2': 'value2',
    'key3': 'value3',
}
my_dict
# Out:
# {'key1': 'value1', 'key2': 'value2', 'key3': 'value3'}

# %%
my_dict['key1']
# Out:
# 'value1'

# %%
d= {'k1': 'v1', 'k2': [1,2,3], 'k3': {'insideKey': 3}}
d
# Out:
# {'k1': 'v1', 'k2': [1, 2, 3], 'k3': {'insideKey': 3}}

# %%
d['k3']['insideKey']
# Out:
# 3

# %%
int(d['k2'][2]) + 2
# Out:
# 5

# %%
d.keys()
# Out:
# dict_keys(['k1', 'k2', 'k3'])

# %%
d.values()
# Out:
# dict_values(['v1', [1, 2, 3], {'insideKey': 3}])

# %%
d.items()
# Out:
# dict_items([('k1', 'v1'), ('k2', [1, 2, 3]), ('k3', {'insideKey': 3})])

# %% [markdown]
# Tuples (immutables and ordered)

# %%
my_tuple = (1,2,3)
my_tuple
# Out:
# (1, 2, 3)

# %%
my_tuple = ('one', 2, 'three', 2)
my_tuple
# Out:
# ('one', 2, 'three', 2)

# %%
my_tuple[-1]
# Out:
# 2

# %%
[1,1,2].count(1)
# Out:
# 2

# %%
[1,1,2].index(2)
# Out:
# 2

# %%
my_tuple.count(2)
# Out:
# 2

# %% [markdown]
# Sets (unordered and mutable)

# %%
my_sets = {1,2,3}
my_sets
# Out:
# {1, 2, 3}

# %%
my_sets.add(4)
my_sets
# Out:
# {1, 2, 3, 4}

# %%
my_sets.add(4)
my_sets
# Out:
# {1, 2, 3, 4}

# %%
# converting list to set to remove duplicates
duplicated_list = [3,3,3,3,3,1,1,1,1,2,2,2,2]
set(duplicated_list)
# Out:
# {1, 2, 3}

# %% [markdown]
# Booleans

# %%
False
# Out:
# False

# %%
True
# Out:
# True

# %%
type(True)
# Out:
# bool
